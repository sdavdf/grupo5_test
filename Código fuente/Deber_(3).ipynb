# %%
# !pip install pycryptodomex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycryptodomex
#   Downloading pycryptodomex-3.18.0-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 38.3 MB/s eta 0:00:00
# Installing collected packages: pycryptodomex
# Successfully installed pycryptodomex-3.18.0

# %%
from cryptography.hazmat.primitives.ciphers import Cipher, algorithms
from cryptography.hazmat.primitives.ciphers.aead import ChaCha20Poly1305
from cryptography.hazmat.backends import default_backend
from pathlib import Path
from Cryptodome.Cipher import AES
from Cryptodome.Random import get_random_bytes
from Cryptodome.Util.Padding import pad, unpad
from time import time
import random
import hashlib

# %%
from google.colab import files
import os

# %%
book=files.upload

# %%
start_time1 = time()
book = Path("lorem16.txt").read_text().encode("utf-8")
print(book)
encryption_time1 = time() - start_time1
print("Tiempo de lectura del archivo: {} segundos".format(encryption_time1))
# Out:
# b'Lorem ipsum dolor sit amet consectetur adipisicing elit. Optio minima perspiciatis fugit aperiam mollitia porro quam quis deserunt repellendus, sapiente quas pariatur nobis nihil exercitationem obcaecati iste, qui animi quaerat odit ad eveniet soluta? Magnam explicabo iure corporis beatae quidem, eveniet, ducimus exercitationem voluptates ratione consequuntur iste deserunt dolor atque laborum excepturi facere perspiciatis, nisi nam harum quas reiciendis eaque doloribus! Vitae atque obcaecati dolores dolore facilis, recusandae possimus ipsum voluptate optio perferendis cum animi laudantium magnam laboriosam minima! Nam repellendus quia perspiciatis adipisci accusantium ut neque molestiae, dolore consequuntur assumenda libero magnam nostrum consequatur cupiditate, non temporibus maiores suscipit aperiam quo nulla! Reprehenderit, eius placeat perferendis facilis odio doloribus? Aperiam cumque quaerat suscipit. Maxime facere ratione, nesciunt blanditiis similique quia mollitia officia nobis incidunt accusantium veritatis temporibus magnam quod autem earum cum debitis! Maxime itaque quas, eos, necessitatibus dolorum totam omnis voluptates minima numquam similique harum ipsam quidem repellendus sint asperiores non cupiditate eaque, neque ratione excepturi officiis! Reprehenderit aperiam repellat, autem cum officia quidem, quis expedita eveniet, velit sint pariatur nisi illum architecto dolorem minima voluptatum amet nobis ut odit quaerat eaque odio maiores culpa. Ducimus obcaecati vitae accusamus praesentium sequi placeat repudiandae illo, recusandae vero, dolorem hic voluptate officiis, cupiditate soluta sint sed. Ducimus consectetur, cupiditate eaque accusantium quis sequi blanditiis! Debitis ad eum aliquam? Eveniet esse, corporis officiis fuga neque iusto inventore praesentium voluptas. Necessitatibus amet architecto possimus cum rerum provident alias nihil vel consequuntur dolore nostrum ut, deleniti consequatur? Explicabo placeat perferendis, atque, reiciendis laborum provident dolores deleniti autem deserunt aliquid, illo tempora molestiae aperiam! Ullam eos modi consequuntur soluta non alias enim inventore, ipsam iusto placeat, dolore dolores quisquam officia ratione nisi repudiandae deleniti veniam a? Et blanditiis voluptatum ab, amet dolorum expedita cumque consectetur voluptatibus officia assumenda rerum quam quidem quia, odit perferendis magnam explicabo sapiente dignissimos culpa unde ipsum sit praesentium! Animi adipisci excepturi maxime doloremque, nobis nam aperiam aut. Similique incidunt sapiente totam laudantium tenetur inventore cumque debitis id aliquam a distinctio veritatis quibusdam autem, sint nostrum recusandae pariatur. Dolore adipisci nemo eligendi exercitationem dicta sequi veritatis est itaque vitae rerum iste, architecto voluptatibus tempore, ab, repellat soluta sint possimus unde accusamus suscipit numquam. Nulla excepturi recusandae quibusdam aliquid voluptatibus nihil ea voluptas non porro voluptatum neque, at alias aliquam? Labore at repellat aliquam in repellendus, repudiandae, mollitia atque harum quis quae non, commodi praesentium ratione optio ex qui asperiores unde! Reprehenderit voluptates quasi ipsam veritatis inventore eveniet corporis, mollitia quaerat iste esse suscipit quae id pariatur, accusamus fuga debitis alias rem eum cum enim nemo, explicabo ratione nisi! Minus tenetur perferendis dignissimos illo odio, vero cum, provident atque molestias eum sunt, obcaecati harum laudantium? Quis deleniti perferendis aperiam, voluptas asperiores neque eveniet expedita, error sequi nobis facilis officiis quam facere temporibus? Quae amet temporibus nostrum doloremque dignissimos fugiat molestias cumque. Provident dicta tempore illo doloremque ut vel distinctio atque, dolore sequi commodi, eligendi iste voluptatibus eos accusamus mollitia, deserunt voluptas labore ea eum nostrum neque est voluptatem porro? Vitae labore reiciendis ut, amet odio dolorem saepe, ad libero cupiditate veritatis sint! Erro ...
# Tiempo de lectura del archivo: 0.013240337371826172 segundos

# %% [markdown]
# Cifrado chacha-20

# %%
#Cifrado chacha-20 claves
start_time2 = time()
key = get_random_bytes(32)  # Clave de 256 bits (32 bytes)
nonce = get_random_bytes(16)
print(key,nonce)
encryption_time2 = time() - start_time2
print("Tiempo de generación de claves: {} segundos".format(encryption_time2))
# Out:
# b'\x90\\\x9c\xe3\xf3\x95`\x99\x83J\xfe\xb8"\xd8P\x0f\x1c\x9d\xbcn1\xb1\xc6(\xc5|^?\x01\xbdQE' b'}\x99\xdb\x8a\x1e\xe7eI\x94}\x83\x98\xd0\xa8\xbd\xbc'
# Tiempo de generación de claves: 0.0015583038330078125 segundos

# %%
#Cifrar texto
start_time3 = time()
cipher = Cipher(algorithms.ChaCha20(key, nonce), mode=None)
encryptor = cipher.encryptor()
ciphertext = encryptor.update(book) + encryptor.finalize()
print(ciphertext.hex())
encryption_time3 = time() - start_time3
print("Tiempo de cifrado: {} segundos".format(encryption_time3))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#Decifrar texto
start_time4 = time()
cipher = Cipher(algorithms.ChaCha20(key, nonce), mode=None)
decryptor = cipher.decryptor()
plaintext = decryptor.update(ciphertext) + decryptor.finalize()
print(plaintext.decode())
encryption_time4 = time() - start_time4
print("Tiempo de descifrado: {} segundos".format(encryption_time4))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Cifrado AES

# %% [markdown]
# Claves

# %%
start_time1 = time()
key = get_random_bytes(16)  # Clave de 16 bytes (128 bits)
iv = get_random_bytes(AES.block_size)
print(key,iv)
encryption_time1 = time() - start_time1
print("Tiempo de generación de claves: {} segundos".format(encryption_time1))
# Out:
# b'\xf9J\x95\xb0\x05;JA\xe6\x96\xd5\x11I\x8c\x08c' b"\xa6'\x1c39\xec\x11>\x00\xe6\xcdA^\xde\x0e\xd8"
# Tiempo de generación de claves: 0.002209186553955078 segundos

# %% [markdown]
# Cifrado

# %%
start_time1 = time()
cipher = AES.new(key, AES.MODE_CBC, iv)
ciphertext = cipher.encrypt(pad(book, AES.block_size))
print(book.hex())
encryption_time1 = time() - start_time1
print("Tiempo de cifrado del archivo: {} segundos".format(encryption_time1))
# Out:
# ...
# Tiempo de cifrado del archivo: 0.009591341018676758 segundos

# %% [markdown]
# Decifrado

# %%
start_time1 = time()
cipher = AES.new(key, AES.MODE_CBC, iv)
book = unpad(cipher.decrypt(ciphertext), AES.block_size)
print(book.decode())
encryption_time1 = time() - start_time1
print("Tiempo de descifrado del archivo: {} segundos".format(encryption_time1))
# Out:
# Lorem ipsum dolor sit amet consectetur adipisicing elit. Optio minima perspiciatis fugit aperiam mollitia porro quam quis deserunt repellendus, sapiente quas pariatur nobis nihil exercitationem obcaecati iste, qui animi quaerat odit ad eveniet soluta? Magnam explicabo iure corporis beatae quidem, eveniet, ducimus exercitationem voluptates ratione consequuntur iste deserunt dolor atque laborum excepturi facere perspiciatis, nisi nam harum quas reiciendis eaque doloribus! Vitae atque obcaecati dolores dolore facilis, recusandae possimus ipsum voluptate optio perferendis cum animi laudantium magnam laboriosam minima! Nam repellendus quia perspiciatis adipisci accusantium ut neque molestiae, dolore consequuntur assumenda libero magnam nostrum consequatur cupiditate, non temporibus maiores suscipit aperiam quo nulla! Reprehenderit, eius placeat perferendis facilis odio doloribus? Aperiam cumque quaerat suscipit. Maxime facere ratione, nesciunt blanditiis similique quia mollitia officia nobis incidunt accusantium veritatis temporibus magnam quod autem earum cum debitis! Maxime itaque quas, eos, necessitatibus dolorum totam omnis voluptates minima numquam similique harum ipsam quidem repellendus sint asperiores non cupiditate eaque, neque ratione excepturi officiis! Reprehenderit aperiam repellat, autem cum officia quidem, quis expedita eveniet, velit sint pariatur nisi illum architecto dolorem minima voluptatum amet nobis ut odit quaerat eaque odio maiores culpa. Ducimus obcaecati vitae accusamus praesentium sequi placeat repudiandae illo, recusandae vero, dolorem hic voluptate officiis, cupiditate soluta sint sed. Ducimus consectetur, cupiditate eaque accusantium quis sequi blanditiis! Debitis ad eum aliquam? Eveniet esse, corporis officiis fuga neque iusto inventore praesentium voluptas. Necessitatibus amet architecto possimus cum rerum provident alias nihil vel consequuntur dolore nostrum ut, deleniti consequatur? Explicabo placeat perferendis, atque, reiciendis laborum provident dolores deleniti autem deserunt aliquid, illo tempora molestiae aperiam! Ullam eos modi consequuntur soluta non alias enim inventore, ipsam iusto placeat, dolore dolores quisquam officia ratione nisi repudiandae deleniti veniam a? Et blanditiis voluptatum ab, amet dolorum expedita cumque consectetur voluptatibus officia assumenda rerum quam quidem quia, odit perferendis magnam explicabo sapiente dignissimos culpa unde ipsum sit praesentium! Animi adipisci excepturi maxime doloremque, nobis nam aperiam aut. Similique incidunt sapiente totam laudantium tenetur inventore cumque debitis id aliquam a distinctio veritatis quibusdam autem, sint nostrum recusandae pariatur. Dolore adipisci nemo eligendi exercitationem dicta sequi veritatis est itaque vitae rerum iste, architecto voluptatibus tempore, ab, repellat soluta sint possimus unde accusamus suscipit numquam. Nulla excepturi recusandae quibusdam aliquid voluptatibus nihil ea voluptas non porro voluptatum neque, at alias aliquam? Labore at repellat aliquam in repellendus, repudiandae, mollitia atque harum quis quae non, commodi praesentium ratione optio ex qui asperiores unde! Reprehenderit voluptates quasi ipsam veritatis inventore eveniet corporis, mollitia quaerat iste esse suscipit quae id pariatur, accusamus fuga debitis alias rem eum cum enim nemo, explicabo ratione nisi! Minus tenetur perferendis dignissimos illo odio, vero cum, provident atque molestias eum sunt, obcaecati harum laudantium? Quis deleniti perferendis aperiam, voluptas asperiores neque eveniet expedita, error sequi nobis facilis officiis quam facere temporibus? Quae amet temporibus nostrum doloremque dignissimos fugiat molestias cumque. Provident dicta tempore illo doloremque ut vel distinctio atque, dolore sequi commodi, eligendi iste voluptatibus eos accusamus mollitia, deserunt voluptas labore ea eum nostrum neque est voluptatem porro? Vitae labore reiciendis ut, amet odio dolorem saepe, ad libero cupiditate veritatis sint! Error  ...
# Tiempo de descifrado del archivo: 0.0050923824310302734 segundos

# %% [markdown]
# Hellman

# %% [markdown]
# Claves

# %%
def power_modulo(base, exponent, modulus):
    result = 1
    while exponent > 0:
        if exponent % 2 == 1:
            result = (result * base) % modulus
        base = (base * base) % modulus
        exponent //= 2
    return result
prime = 98764321261
generator = 5
def generate_keys(prime, generator):
    private_key = random.randint(2, prime - 2)
    public_key = power_modulo(generator, private_key, prime)
    return (private_key, public_key)

def generate_shared_secret(private_key, public_key, prime):
    shared_secret = power_modulo(public_key, private_key, prime)
    return shared_secret
alice_private_key, alice_public_key = generate_keys(prime, generator)
print("Clave publica Alice",alice_public_key)
print("Clave privada Alice",alice_private_key)
# Generar las claves de Bob
bob_private_key, bob_public_key = generate_keys(prime, generator)
print("Clave publica Bob",bob_public_key)
print("Clave privada Bob",bob_private_key)
# Out:
# Clave publica Alice 44567890624
# Clave privada Alice 23395990845
# Clave publica Bob 73916785429
# Clave privada Bob 45663064589

# %% [markdown]
# SHA 512

# %% [markdown]
# Claves

# %%
hash_object = hashlib.sha512()
print(hash_object.hexdigest())
# Out:
# cf83e1357eefb8bdf1542850d66d8007d620e4050b5715dc83f4a921d36ce9ce47d0d13c5d85f2b0ff8318d2877eec2f63b931bd47417a81a538327af927da3e

# %%
def sha512_hash(message):
    hash_object = hashlib.sha512()
    hash_object.update(message)
    return hash_object.hexdigest()
sha512_result = sha512_hash(book)
print("Mensaje:", book)
print("Hash SHA-512:", sha512_result)
# Out:
# Mensaje:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
